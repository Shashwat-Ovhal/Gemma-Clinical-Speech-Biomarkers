# %% [markdown]
# # BSPC Training Pipeline — Colab Runner
# This notebook isolates the heavy PyTorch `wav2vec 2.0` training loop to Google Colab's free GPUs.

# %%
# 1. Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# %%
# 2. Unzip your project folder (CHANGE the zip file name if necessary)
# !unzip -q "/content/drive/MyDrive/Gemma-Clinical-Speech-Biomarkers.zip" -d "/content/project/"
# %cd /content/project/Gemma-Clinical-Speech-Biomarkers

# %%
# 3. Install required dependencies
# !pip install -r requirements.txt
# !pip install transformers torch torchvision torchaudio

# %%
# 4. Run the full BSPC ablation study!
# !python bspc_train.py

# %%
# 5. Zip the outputs and copy them back to your Google Drive
# !zip -r /content/drive/MyDrive/bspc_outputs.zip ./outputs/bspc/
# !zip -r /content/drive/MyDrive/bspc_models.zip ./medgemma_pd/models/
print("Training complete! Download bspc_outputs.zip and bspc_models.zip from your Google Drive and extract them to your PC's project folder.")
